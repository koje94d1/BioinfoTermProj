# %% [markdown]
# # 생물정보학 및 실습 1 - Term Project용 환경 셋업
#
# ```
# 생물정보학 및 실습 1
# 서울대학교 생물정보학전공/생명과학부 2024년 1학기
#
# 이 노트북은 Creative Commons BY-SA 조건으로 재사용 가능합니다.
# 장혜식 <hyeshik@snu.ac.kr>, 서울대학교 생명과학부
# ```
#
# 이 노트북은 Google Colab을 이용해서 Term Project를 할 수 있도록 환경을 준비해 줍니다. 터미널 사용이 원활하지 않은 상태이고, 데이터를 오랫동안 보관하기 어렵기 때문에 되도록 개인용 컴퓨터에서 [Anaconda](https://www.anaconda.com/)나 [JupyterLab](https://jupyterlab.readthedocs.io/en/stable/) 등을 설치하고 사용하시는 것이 편하지만, 개인용 컴퓨터 사양이 부족한 경우에는 Google CoLab을 사용할 수도 있습니다. 개인용 컴퓨터를 쓸 때는 Windows에서는 [WSL2](https://docs.microsoft.com/en-us/windows/wsl/install-win10)를 쓰시면 리눅스 커맨드라인 환경을 쓸 수 있습니다. Google Colab은 창을 닫은 후 90분 후, 또는 창을 처음 열고 12시간 후에 환경을 닫아버리기 때문에 매번 실습할 때마다 새로 셋업이 필요합니다. `Runtime->Run All`을 실행해서 전체를 한 번 실행하시면 준비됩니다. 모든 것이 잘 안 되고 뭔가 꼬인 느낌이 강하게 들 때는 `Runtime->Factory reset runtime`을 누르고 새로 시작하시면 될 수도 있습니다.

# %% [markdown]
# ## Google Drive 마운트
#
# 데이터 파일들을 불러오고 저장하기 위해서 Google Drive를 연결합니다. **이번엔 스크립트 파일을 편집해야 하기 때문에 Google Drive 마운트를 하지 않으면 vim등 콘솔에서 쓸 수 있는 에디터를 쓰셔야 합니다.** 화면에 나오는 주소를 눌러서 인증하고 인증 코드를 그 아래에 입력하세요. 그러면 `/contents/drive/MyDrive`에서 자신의 Drive 최상단 폴더가 보입니다. Google CoLab에서 접속하지 않고, 본인 컴퓨터 또는 연구실 워크스테이션 등 다른 컴퓨터를 쓰시는 경우에는 저장공간이 충분하므로 이 부분은 생략하고 지나갑니다.

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# ## 실습용 Bioconda 환경 설치하기
# Google CoLab에서 접속하지 않고, 본인 컴퓨터 또는 연구실 워크스테이션 등 다른 컴퓨터를 쓰시는 경우에는 따로 실습용 [Bioconda](https://bioconda.github.io/) 환경을 구축해서 이 노트북을 그 환경 안에서 띄우시면 됩니다.
#
# CoLab을 쓰시는 분들은 다음에 따라서 실습용 프로그램들을 쉽게 설치할 수 있도록 [Bioconda](https://bioconda.github.io/) 환경을 만듭니다. 실행하고 진행상황을 관찰하다가 에러로 보이는 것이 있으면 잘 읽어보고 해결합니다.
#
# 파이썬 모듈들은 Colab쪽의 파이썬 인터프리터를 바꿀 수 없기 때문에 Conda에 설치하더라도 사용하기 어렵습니다. 파이썬 모듈은 `pip` 명령어로 설치하시면 Colab에서 불러와서 사용할 수 있습니다.
#
# 환경 초기화에 관련된 스크립트는 [GitHub 프로젝트](https://github.com/hyeshik/colab-biolab)에 있습니다.

# %%
# !git clone https://github.com/hyeshik/colab-biolab.git
# !cd colab-biolab && bash tools/setup.sh
exec(open('colab-biolab/tools/activate_conda.py').read())
# Out:
# ^C
# ^C
# ---------------------------------------------------------------------------
#
# FileNotFoundError                         Traceback (most recent call last)
#
# Cell In[1], line 3
#
#       1 get_ipython().system('git clone https://github.com/hyeshik/colab-biolab.git')
#
#       2 get_ipython().system('cd colab-biolab && bash tools/setup.sh')
#
# ----> 3 exec(open('colab-biolab/tools/activate_conda.py').read())
#
#
#
# File ~/conda/envs/bioinfo/lib/python3.12/site-packages/IPython/core/interactiveshell.py:324, in _modified_open(file, *args, **kwargs)
#
#     317 if file in {0, 1, 2}:
#
#     318     raise ValueError(
#
#     319         f"IPython won't let you open fd={file} by default "
#
#     320         "as it is likely to crash IPython. If you know what you are doing, "
#
#     321         "you can use builtins' open."
#
#     322     )
#
# --> 324 return io_open(file, *args, **kwargs)
#
#
#
# ...

# %% [markdown]
# Google CoLab에서 shell command를 실행할 때는 명령 앞에 !을 붙이면 실행할 수 있습니다.

# %% [markdown]
# ## 시퀀싱 데이터 다운로드
# 이제 실습 수업에서 필요한 시퀀싱 데이터를 다운로드 받아서 설치합시다. 드라이브 공간만 충분하면 데이터는 계속 저장돼 있기 때문에 학기 전체를 통해서 딱 한 번만 하시면 됩니다. Colab에서는 작업용 데이터를 Google Drive 폴더 아래의 `binfo-datapack1`에 저장합니다. 실습용 데이터는 `/content/drive/MyDrive/binfo1-datapack1`에 풀리게 됩니다.
#
# ### (Option 1) Google CoLab에서 접속한 경우
# 1. [Google Drive 공유폴더](https://drive.google.com/drive/folders/1QBJednh-C7A17PFOlpZHBKyDmBvd6klh?usp=sharing)에 접속합니다.
# 1. 중간 제목줄의 "binfo1-datapack1 ▾"에서 ▾을 누릅니다.
# 1. Add shortcut to Drive를 누릅니다.
# 1. My Drive를 선택해서 ADD SHORTCUT 버튼을 누릅니다.
# 1. 다음 cell을 실행해서 링크가 제대로 들어왔는지 확인합니다. (바로 확인되지 않으면 3–5분 정도 기다렸다가 하면 됩니다.)
# 1. 제대로 확인되면 다음으로 넘어갑니다.

# %%
# !ls -al /content/drive/MyDrive/binfo1-datapack1/

# %% [markdown]
# ### (Option 2) CoLab외의 다른 환경에서 접속한 경우
# 본인 컴퓨터나 연구실 워크스테이션 등에서 작업하는 경우에는 다음 명령어로 다운로드 받으시면 됩니다. 첫 번째에는 wget이 접속오류를 내는 경우가 많으니, 접속에러가 발생하면 다시 한 번 실행해 보세요. `/content/drive/Mydrive` 부분은 원하는 저장 경로로 바꿔서 지정하시면 됩니다.

# %%
# !wget -O - --no-check-certificate https://hyeshik.qbio.io/binfo/binfo1-datapack1.tar | tar -C /rna/seojin/proj/bioinfo_term_proj -xf -
# Out:
# ^C

# %% [markdown]
# 그리고, GENCODE Annotation 데이터도 미리 받아서 저장해 둡니다. 에러가 나면 다시 한 번 실행해 봅니다.

# %%
# !wget --no-check-certificate -O binfo1-datapack1/gencode.gtf.gz http://ftp.ebi.ac.uk/pub/databases/gencode/Gencode_mouse/release_M27/gencode.vM27.annotation.gtf.gz

# %% [markdown]
# ### 파일 체크섬 확인
#
# 받은 데이터의 MD5 체크섬을 확인합니다. 한참 걸립니다. 각 파일들의 원래 체크섬은 다음과 같습니다. 한 번 비교해 보세요. (나중에 자동으로 비교하고 싶으시면 `md5sum -c` 옵션을 사용하면 됩니다. 여기서는 MD5를 처음 써 보는 의미에서 직접 비교해 봅시다.)
#
# ```
# 140aaf30bcb9276cc716f8699f04ddd6  CLIP-35L33G.bam
# f1b3336ed7e2f97d562dcc71641251bd  CLIP-35L33G.bam.bai
# 328883a73d507eafbf5b60bd6b906201  RNA-control.bam
# 02073818e2f398a73c3b76e5169de1ca  RNA-control.bam.bai
# b09550d09d6c2a4ce27f0226f426fdb1  RNA-siLin28a.bam
# fef112c727244060ea62d3f2564a07f6  RNA-siLin28a.bam.bai
# 28bbd0c47d725669340c784f1b772c01  RNA-siLuc.bam
# 43590fdc4d81905c0432e0d1cb8cfd5b  RNA-siLuc.bam.bai
# 5c08a9297307bc83259e658c4474f0cc  RPF-siLin28a.bam
# a1bb3e29be412dfd7fd8d16b1b1acc4c  RPF-siLin28a.bam.bai
# f2eebf50943024d0116c9cd3e744c707  RPF-siLuc.bam
# dc24f69e8f571fc8be30f28ce5b84fcd  RPF-siLuc.bam.bai
# ```

# %%
# !md5sum binfo1-datapack1/*

# %% [markdown]
# 140aaf30bcb9276cc716f8699f04ddd6  binfo1-datapack1/CLIP-35L33G.bam
# f1b3336ed7e2f97d562dcc71641251bd  binfo1-datapack1/CLIP-35L33G.bam.bai
# 794eb8d273987a094dcc013afa2a1956  binfo1-datapack1/gencode.gtf.gz
# 328883a73d507eafbf5b60bd6b906201  binfo1-datapack1/RNA-control.bam
# 02073818e2f398a73c3b76e5169de1ca  binfo1-datapack1/RNA-control.bam.bai
# b09550d09d6c2a4ce27f0226f426fdb1  binfo1-datapack1/RNA-siLin28a.bam
# fef112c727244060ea62d3f2564a07f6  binfo1-datapack1/RNA-siLin28a.bam.bai
# 28bbd0c47d725669340c784f1b772c01  binfo1-datapack1/RNA-siLuc.bam
# 43590fdc4d81905c0432e0d1cb8cfd5b  binfo1-datapack1/RNA-siLuc.bam.bai
# 5c08a9297307bc83259e658c4474f0cc  binfo1-datapack1/RPF-siLin28a.bam
# a1bb3e29be412dfd7fd8d16b1b1acc4c  binfo1-datapack1/RPF-siLin28a.bam.bai
# f2eebf50943024d0116c9cd3e744c707  binfo1-datapack1/RPF-siLuc.bam
# dc24f69e8f571fc8be30f28ce5b84fcd  binfo1-datapack1/RPF-siLuc.bam.bai

# %%
# !ls -al binfo*

# %% [markdown]
# total 6301792
# drwxr-xr-x 1 seojin rna        428 May  8 13:34 .
# drwxr-xr-x 1 seojin rna         86 May  8 13:33 ..
# -rw-r--r-- 1 seojin rna 1370036258 May  6  2021 CLIP-35L33G.bam
# -rw-r--r-- 1 seojin rna    3118336 May  6  2021 CLIP-35L33G.bam.bai
# -rw-r--r-- 1 seojin rna   28359457 Mar  9  2021 gencode.gtf.gz
# -rw-r--r-- 1 seojin rna 1003658801 May  6  2021 RNA-control.bam
# -rw-r--r-- 1 seojin rna    2276104 May  6  2021 RNA-control.bam.bai
# -rw-r--r-- 1 seojin rna 1260991122 May  6  2021 RNA-siLin28a.bam
# -rw-r--r-- 1 seojin rna    2710744 May  6  2021 RNA-siLin28a.bam.bai
# -rw-r--r-- 1 seojin rna  981684502 May  6  2021 RNA-siLuc.bam
# -rw-r--r-- 1 seojin rna    2606104 May  6  2021 RNA-siLuc.bam.bai
# -rw-r--r-- 1 seojin rna  737352902 May  6  2021 RPF-siLin28a.bam
# -rw-r--r-- 1 seojin rna    2482768 May  6  2021 RPF-siLin28a.bam.bai
# -rw-r--r-- 1 seojin rna 1055123479 May  6  2021 RPF-siLuc.bam
# -rw-r--r-- 1 seojin rna    2605912 May  6  2021 RPF-siLuc.bam.bai

# %% [markdown]
# 실습에 필요한 프로그램들 몇 가지를 추가로 설치합니다.

# %%
# !conda install -y subread

# %% [markdown]
# ## Transcript count table 마련하기
#
# 제공된 alignment와 annotation 파일들을 이용해서 transcript별 read count를 구해봅니다. 실제 연구에서는 multi-mapping 등을 고려해야 하지만, 여기서는 단순화해서 모두 무시합니다.

# %% [markdown]
# 먼저 작업 디렉토리를 만들고 데이터를 원본 디렉토리에서 복사해 옵니다. (이미 이 노트북을 실행한 적이 있으면 다시 할 필요는 없습니다.)

# %%
# !mkdir binfo1-work
# !rsync -Pav binfo1-datapack1/ binfo1-work/

# %%
# %cd binfo1-work
# Out:
# /rna/seojin/proj/bioinformatics/bioinfo_term_proj/binfo1-work

# %% [markdown]
# 자! bam 파일에 담긴 aligned reads와 gtf 파일에 담긴 gene annotation으로 gene별 read count를 구합니다.

# %%
# !featureCounts -a gencode.gtf -o read-counts.txt *.bam

# %% [markdown]
# (bioinfo) ➜  binfo1-work featureCounts -a gencode.gtf -o read-counts.txt *.bam
#
#         ==========     _____ _    _ ____  _____  ______          _____
#         =====         / ____| |  | |  _ \|  __ \|  ____|   /\   |  __ \
#           =====      | (___ | |  | | |_) | |__) | |__     /  \  | |  | |
#             ====      \___ \| |  | |  _ <|  _  /|  __|   / /\ \ | |  | |
#               ====    ____) | |__| | |_) | | \ \| |____ / ____ \| |__| |
#         ==========   |_____/ \____/|____/|_|  \_\______/_/    \_\_____/
#           v2.0.6
#
# //========================== featureCounts setting ===========================\\
# ||                                                                            ||
# ||             Input files : 6 BAM files                                      ||
# ||                                                                            ||
# ||                           CLIP-35L33G.bam                                  ||
# ||                           RNA-control.bam                                  ||
# ||                           RNA-siLin28a.bam                                 ||
# ||                           RNA-siLuc.bam                                    ||
# ||                           RPF-siLin28a.bam                                 ||
# ||                           RPF-siLuc.bam                                    ||
# ||                                                                            ||
# ||             Output file : read-counts.txt                                  ||
# ||                 Summary : read-counts.txt.summary                          ||
# ||              Paired-end : no                                               ||
# ||        Count read pairs : no                                               ||
# ||              Annotation : gencode.gtf (GTF)                                ||
# ||      Dir for temp files : ./                                               ||
# ||                                                                            ||
# ||                 Threads : 1                                                ||
# ||                   Level : meta-feature level                               ||
# ||      Multimapping reads : not counted                                      ||
# || Multi-overlapping reads : not counted                                      ||
# ||   Min overlapping bases : 1                                                ||
# ||                                                                            ||
# \\============================================================================//
#
# //================================= Running ==================================\\
# ||                                                                            ||
# || Load annotation file gencode.gtf ...                                       ||
# ||    Features : 841952                                                       ||
# ||    Meta-features : 55359                                                   ||
# ||    Chromosomes/contigs : 22                                                ||
# ||                                                                            ||
# || Process BAM file CLIP-35L33G.bam...                                        ||
# ||    Single-end reads are included.                                          ||
# ||    Total alignments : 38880853                                             ||
# ||    Successfully assigned alignments : 13630945 (35.1%)                     ||
# ||    Running time : 0.36 minutes                                             ||
# ||                                                                            ||
# || Process BAM file RNA-control.bam...                                        ||
# ||    Single-end reads are included.                                          ||
# ||    Total alignments : 24971058                                             ||
# ||    Successfully assigned alignments : 5200836 (20.8%)                      ||
# ||    Running time : 0.24 minutes                                             ||
# ||                                                                            ||
# || Process BAM file RNA-siLin28a.bam...                                       ||
# ||    Single-end reads are included.                                          ||
# ||    Total alignments : 35108178                                             ||
# ||    Successfully assigned alignments : 12338280 (35.1%)                     ||
# ||    Running time : 0.33 minutes                                             ||
# ||                                                                            ||
# || Process BAM file RNA-siLuc.bam...                                          ||
# ||    Single-end reads are included.                                          ||
# ||    Total alignments : 28117241                                             ||
# ||    Successfully assigned alignments : 9748787 (34.7%)                      ||
# ||    Running time : 0.26 minutes                                             ||
# ||                                                                            ||
# || Process BAM file RPF-siLin28a.bam...                                       ||
# ||    Single-end reads are included.                                          ||
# ||    Total alignments : 30095551                                             ||
# ||    Successfully assigned alignments : 10694162 (35.5%)                     ||
# ||    Running time : 0.23 minutes                                             ||
# ||                                                                            ||
# || Process BAM file RPF-siLuc.bam...                                          ||
# ||    Single-end reads are included.                                          ||
# ||    Total alignments : 42002435                                             ||
# ||    Successfully assigned alignments : 12932285 (30.8%)                     ||
# ||    Running time : 0.32 minutes                                             ||
# ||                                                                            ||
# || Write the final count table.                                               ||
# || Write the read assignment summary.                                         ||
# ||                                                                            ||
# || Summary of counting results can be found in file "read-counts.txt.summary  ||
# || "                                                                          ||
# ||                                                                            ||
# \\============================================================================//

# %% [markdown]
# 결과를 pandas로 읽어와 봅니다.

# %%
import pandas as pd
cnts = pd.read_csv('read-counts.txt', sep='\t', comment='#', index_col=0)
cnts.head()
# Out:
#                                                      Chr  \
# Geneid
# ENSMUSG00000102693.2                                chr1
# ENSMUSG00000064842.3                                chr1
# ENSMUSG00000051951.6  chr1;chr1;chr1;chr1;chr1;chr1;chr1
# ENSMUSG00000102851.2                                chr1
# ENSMUSG00000103377.2                                chr1
#
#                                                                   Start  \
# Geneid
# ENSMUSG00000102693.2                                            3143476
# ENSMUSG00000064842.3                                            3172239
# ENSMUSG00000051951.6  3276124;3276746;3283662;3283832;3284705;349192...
# ENSMUSG00000102851.2                                            3322980
# ENSMUSG00000103377.2                                            3435954
#
#                                                                     End  \
# Geneid
# ENSMUSG00000102693.2                                            3144545
# ...

# %% [markdown]
# 이제 한 번 대충 그림을 그려 봅니다.

# %%
cnts['clip_enrichment'] = cnts['CLIP-35L33G.bam'] / cnts['RNA-control.bam']
cnts['rden_change'] = (cnts['RPF-siLin28a.bam'] / cnts['RNA-siLin28a.bam']) / (cnts['RPF-siLuc.bam'] / cnts['RNA-siLuc.bam'])
cnts.head()
# Out:
#                                                      Chr  \
# Geneid
# ENSMUSG00000102693.2                                chr1
# ENSMUSG00000064842.3                                chr1
# ENSMUSG00000051951.6  chr1;chr1;chr1;chr1;chr1;chr1;chr1
# ENSMUSG00000102851.2                                chr1
# ENSMUSG00000103377.2                                chr1
#
#                                                                   Start  \
# Geneid
# ENSMUSG00000102693.2                                            3143476
# ENSMUSG00000064842.3                                            3172239
# ENSMUSG00000051951.6  3276124;3276746;3283662;3283832;3284705;349192...
# ENSMUSG00000102851.2                                            3322980
# ENSMUSG00000103377.2                                            3435954
#
#                                                                     End  \
# Geneid
# ENSMUSG00000102693.2                                            3144545
# ...

# %%
from matplotlib import pyplot as plt
import numpy as np

fig, ax = plt.subplots(1, 1, figsize=(5, 5))
ax.scatter(np.log2(cnts['clip_enrichment']),
           np.log2(cnts['rden_change']))
# Out:
# /rna/seojin/conda/envs/bioinfo/lib/python3.12/site-packages/pandas/core/arraylike.py:399: RuntimeWarning: divide by zero encountered in log2
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %% [markdown]
# 이 그림에는 문제가 많이 있습니다. 논문의 그림 Figure 4D처럼 한 번 만들어 봅시다~

# %%
# 여기에 코드를 새로 작성해서 논문의 그림과 비슷하게 만들어 봅니다.

new_cnts = cnts.copy()
new_cnts.replace([np.inf, -np.inf], np.nan, inplace=True)
new_cnts.dropna(inplace=True)
new_cnts['clip_enrichment'] = new_cnts['CLIP-35L33G.bam'] / new_cnts['RNA-control.bam']
new_cnts['rden_change'] = (new_cnts['RPF-siLin28a.bam'] / new_cnts['RNA-siLin28a.bam']) / (new_cnts['RPF-siLuc.bam'] / new_cnts['RNA-siLuc.bam'])
new_cnts = new_cnts[(new_cnts['clip_enrichment'] != 0) & (new_cnts['rden_change'] != 0)]
#read_count
read_count = 30
new_cnts = new_cnts[(new_cnts['CLIP-35L33G.bam']>read_count) & (new_cnts['RNA-control.bam']>read_count) & (new_cnts['RPF-siLin28a.bam']>read_count) & (new_cnts['RNA-siLin28a.bam']>read_count) & (new_cnts['RPF-siLuc.bam']>read_count) & (new_cnts['RNA-siLuc.bam']>read_count)]

new_cnts.head()
# Out:
#                                                                      Chr  \
# Geneid
# ENSMUSG00000103922.2                                                chr1
# ENSMUSG00000033845.14  chr1;chr1;chr1;chr1;chr1;chr1;chr1;chr1;chr1;c...
# ENSMUSG00000025903.15  chr1;chr1;chr1;chr1;chr1;chr1;chr1;chr1;chr1;c...
# ENSMUSG00000033813.16  chr1;chr1;chr1;chr1;chr1;chr1;chr1;chr1;chr1;c...
# ENSMUSG00000033793.13  chr1;chr1;chr1;chr1;chr1;chr1;chr1;chr1;chr1;c...
#
#                                                                    Start  \
# Geneid
# ENSMUSG00000103922.2                                             4841354
# ENSMUSG00000033845.14  4843429;4843434;4844659;4846600;4847748;484774...
# ENSMUSG00000025903.15  4878011;4878046;4878053;4878119;4878121;487813...
# ENSMUSG00000033813.16  4928037;4928261;4937693;4937693;4948250;494825...
# ENSMUSG00000033793.13  5140241;5153303;5153333;5153347;5153355;515335...
#
# ...

# %% [markdown]
# ##Trial for normalization (which seems not needed)
# {toggle}

# %%
total_reads = new_cnts.sum(axis=0)
total_reads
# Out:
# Chr                 chr1chr1;chr1;chr1;chr1;chr1;chr1;chr1;chr1;ch...
# Start               48413544843429;4843434;4844659;4846600;4847748...
# End                 48424224844739;4847024;4844739;4847024;4847871...
# Strand              +-;-;-;-;-;-;-;-;-;-;-;-;-;-;-;-;-;-;-;-;-;-;-...
# Length                                                       50231868
# CLIP-35L33G.bam                                              12931188
# RNA-control.bam                                               4765008
# RNA-siLin28a.bam                                             11825594
# RNA-siLuc.bam                                                 9351583
# RPF-siLin28a.bam                                             10266898
# RPF-siLuc.bam                                                12428812
# clip_enrichment                                          22202.139451
# rden_change                                               5403.046337
# dtype: object

# %%
new_cnts['clip_enrichment'] = new_cnts['clip_enrichment'] / total_reads['clip_enrichment'] *1e6
new_cnts['rden_change'] = new_cnts['rden_change'] / total_reads['rden_change'] *1e6
new_cnts.head()

# %%
new_cnts['CLIP-35L33G.bam'] = (new_cnts['CLIP-35L33G.bam'] / total_reads['CLIP-35L33G.bam'])*1e6
new_cnts['RNA-control.bam'] = new_cnts['RNA-control.bam'] / total_reads['RNA-control.bam']*1e6
new_cnts['RPF-siLin28a.bam'] = new_cnts['RPF-siLin28a.bam'] / total_reads['RPF-siLin28a.bam']*1e6
new_cnts['RNA-siLin28a.bam'] = new_cnts['RNA-siLin28a.bam'] / total_reads['RNA-siLin28a.bam']*1e6
new_cnts['RPF-siLuc.bam'] = new_cnts['RPF-siLuc.bam'] / total_reads['RPF-siLuc.bam']*1e6
new_cnts['RNA-siLuc.bam'] = new_cnts['RNA-siLuc.bam'] / total_reads['RNA-siLuc.bam']*1e6
new_cnts.head()
# Out:
#                                                                      Chr  \
# Geneid
# ENSMUSG00000103922.2                                                chr1
# ENSMUSG00000033845.14  chr1;chr1;chr1;chr1;chr1;chr1;chr1;chr1;chr1;c...
# ENSMUSG00000025903.15  chr1;chr1;chr1;chr1;chr1;chr1;chr1;chr1;chr1;c...
# ENSMUSG00000033813.16  chr1;chr1;chr1;chr1;chr1;chr1;chr1;chr1;chr1;c...
# ENSMUSG00000033793.13  chr1;chr1;chr1;chr1;chr1;chr1;chr1;chr1;chr1;c...
#
#                                                                    Start  \
# Geneid
# ENSMUSG00000103922.2                                             4841354
# ENSMUSG00000033845.14  4843429;4843434;4844659;4846600;4847748;484774...
# ENSMUSG00000025903.15  4878011;4878046;4878053;4878119;4878121;487813...
# ENSMUSG00000033813.16  4928037;4928261;4937693;4937693;4948250;494825...
# ENSMUSG00000033793.13  5140241;5153303;5153333;5153347;5153355;515335...
#
# ...

# %%
new_cnts['clip_enrichment'] = new_cnts['CLIP-35L33G.bam'] / new_cnts['RNA-control.bam']
new_cnts['rden_change'] = (new_cnts['RPF-siLin28a.bam'] / new_cnts['RNA-siLin28a.bam']) / (new_cnts['RPF-siLuc.bam'] / new_cnts['RNA-siLuc.bam'])
new_cnts.head()
# Out:
#                                                                      Chr  \
# Geneid
# ENSMUSG00000103922.2                                                chr1
# ENSMUSG00000033845.14  chr1;chr1;chr1;chr1;chr1;chr1;chr1;chr1;chr1;c...
# ENSMUSG00000025903.15  chr1;chr1;chr1;chr1;chr1;chr1;chr1;chr1;chr1;c...
# ENSMUSG00000033813.16  chr1;chr1;chr1;chr1;chr1;chr1;chr1;chr1;chr1;c...
# ENSMUSG00000033793.13  chr1;chr1;chr1;chr1;chr1;chr1;chr1;chr1;chr1;c...
#
#                                                                    Start  \
# Geneid
# ENSMUSG00000103922.2                                             4841354
# ENSMUSG00000033845.14  4843429;4843434;4844659;4846600;4847748;484774...
# ENSMUSG00000025903.15  4878011;4878046;4878053;4878119;4878121;487813...
# ENSMUSG00000033813.16  4928037;4928261;4937693;4937693;4948250;494825...
# ENSMUSG00000033793.13  5140241;5153303;5153333;5153347;5153355;515335...
#
# ...

# %%
avg_len = total_reads['Length']/len(new_cnts)
print(avg_len)
new_cnts['clip_enrichment'] = new_cnts['clip_enrichment'] / (new_cnts['Length'] / avg_len) 
new_cnts['rden_change'] = new_cnts['rden_change'] / (new_cnts['Length'] / avg_len) 
new_cnts.head()
# Out:
# 5639.594476254631
#                                                                      Chr  \
# Geneid
# ENSMUSG00000103922.2                                                chr1
# ENSMUSG00000033845.14  chr1;chr1;chr1;chr1;chr1;chr1;chr1;chr1;chr1;c...
# ENSMUSG00000025903.15  chr1;chr1;chr1;chr1;chr1;chr1;chr1;chr1;chr1;c...
# ENSMUSG00000033813.16  chr1;chr1;chr1;chr1;chr1;chr1;chr1;chr1;chr1;c...
# ENSMUSG00000033793.13  chr1;chr1;chr1;chr1;chr1;chr1;chr1;chr1;chr1;c...
#
#                                                                    Start  \
# Geneid
# ENSMUSG00000103922.2                                             4841354
# ENSMUSG00000033845.14  4843429;4843434;4844659;4846600;4847748;484774...
# ENSMUSG00000025903.15  4878011;4878046;4878053;4878119;4878121;487813...
# ENSMUSG00000033813.16  4928037;4928261;4937693;4937693;4948250;494825...
# ENSMUSG00000033793.13  5140241;5153303;5153333;5153347;5153355;515335...
#
# ...

# %%
# new_cnts['CLIP-35L33G.bam'] = new_cnts['CLIP-35L33G.bam']/new_cnts['Length']
# new_cnts['RNA-control.bam'] = new_cnts['RNA-control.bam']/new_cnts['Length']
# new_cnts['RPF-siLin28a.bam'] = new_cnts['RPF-siLin28a.bam']/new_cnts['Length']
# new_cnts['RNA-siLin28a.bam'] = new_cnts['RNA-siLin28a.bam']/new_cnts['Length']
# new_cnts['RPF-siLuc.bam'] = new_cnts['RPF-siLuc.bam']/new_cnts['Length']
# new_cnts['RNA-siLuc.bam'] = new_cnts['RNA-siLuc.bam']/new_cnts['Length']

# %%
from scipy import stats
r, p = stats.pearsonr(new_cnts['clip_enrichment'], new_cnts['rden_change'])

# %%
fig, ax = plt.subplots(1, 1, figsize=(3, 3))
plt.annotate('r = {:.4f}'.format(r), xy=(0.65, 0.05), xycoords='axes fraction')
plt.xlim(-6, 4)
plt.ylim(-2, 2)
plt.xticks(np.arange(-6, 4.1, 2))
plt.yticks(np.arange(-2, 2.1, 1))
plt.grid(True)
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
ax.scatter(np.log2(new_cnts['clip_enrichment']),
           np.log2(new_cnts['rden_change']), 
           s=0.1, 
           color = 'black',
           alpha = 0.5)




ax.set_xlabel('LIN28A CLIP enrichment ($\log_2$)', fontsize=10)
ax.set_ylabel('Ribosome density change\nupon $\it{LIN28A}$ knockdown ($\log_2$)', fontsize=10)
#title left ordered
ax.set_title('CLIP and ribosome footprinting upon\n$\it{Lin28a}$ knockdown', loc='left')
# Out:
# <>:19: SyntaxWarning: invalid escape sequence '\l'
# <>:20: SyntaxWarning: invalid escape sequence '\i'
# <>:22: SyntaxWarning: invalid escape sequence '\i'
# <>:19: SyntaxWarning: invalid escape sequence '\l'
# <>:20: SyntaxWarning: invalid escape sequence '\i'
# <>:22: SyntaxWarning: invalid escape sequence '\i'
# /tmp/ipykernel_794804/3624069917.py:19: SyntaxWarning: invalid escape sequence '\l'
#   ax.set_xlabel('LIN28A CLIP enrichment ($\log_2$)', fontsize=10)
# /tmp/ipykernel_794804/3624069917.py:20: SyntaxWarning: invalid escape sequence '\i'
#   ax.set_ylabel('Ribosome density change\nupon $\it{LIN28A}$ knockdown ($\log_2$)', fontsize=10)
# /tmp/ipykernel_794804/3624069917.py:22: SyntaxWarning: invalid escape sequence '\i'
#   ax.set_title('CLIP and ribosome footprinting upon\n$\it{Lin28a}$ knockdown', loc='left')
# Text(0.0, 1.0, 'CLIP and ribosome footprinting upon\n$\\it{Lin28a}$ knockdown')

# %% [markdown]
# ## Protein localization 반영하기
#
# 논문 그림(Figure 5B, S6A)에서는 protein localization을 반영해서 색으로 나타냈습니다. 이것을 한 번 구현해 봅시다. 각 gene product의 localization을 따로 구하려면 좀 귀찮기 때문에 미리 모아 두었습니다. UniProt에서 매핑된 데이터를 토대로 아주 명확한 것만 일부 정리한 것입니다. 이것도 마찬가지로 처음엔 에러가 나기도 하니까, 다시 실행해보면 거의 잘 됩니다~

# %%
import ssl
ssl._create_default_https_context = ssl._create_unverified_context
mouselocal = pd.read_csv('https://hyeshik.qbio.io/binfo/mouselocalization-20210507.txt', sep='\t')
mouselocal.head()
# Out:
#               gene_id            Gene names       type
# 0  ENSMUSG00000000001                 Gnai3  cytoplasm
# 1  ENSMUSG00000000028  Cdc45 Cdc45l Cdc45l2    nucleus
# 2  ENSMUSG00000000049            Apoh B2gp1  cytoplasm
# 3  ENSMUSG00000000058                  Cav2  cytoplasm
# 4  ENSMUSG00000000085                 Scmh1    nucleus

# %% [markdown]
# 이제 이 localization 데이터와 위에서 만든 scatter를 결합해서 논문 그림과 비슷하게 만들어 봅시다.

# %%
new_cnts['gene_id'] = new_cnts.index.str.split('.').str[0]
merged = pd.merge(new_cnts, mouselocal, on='gene_id', how='inner')
merged['type'].head(20)
# Out:
# 0             cytoplasm
# 1               nucleus
# 2             cytoplasm
# 3               nucleus
# 4             cytoplasm
# 5               nucleus
# 6               nucleus
# 7               nucleus
# 8               nucleus
# 9               nucleus
# 10              nucleus
# 11              nucleus
# 12    integral membrane
# 13            cytoplasm
# 14    integral membrane
# 15              nucleus
# 16    integral membrane
# 17    integral membrane
# 18    integral membrane
# 19    integral membrane
# Name: type, dtype: object

# %%
fig, ax = plt.subplots(1, 1, figsize=(3, 3))
# plt.annotate('r = {:.4f}'.format(r), xy=(0.65, 0.05), xycoords='axes fraction')
plt.xlim(-6, 4)
plt.ylim(-2, 3)
plt.xticks(np.arange(-6, 4.1, 2))
plt.yticks(np.arange(-2, 3.1, 1))
plt.grid(axis='y')
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
#color codition

color_dict = {'nucleus':'blue', 'cytoplasm':'green', 'integral membrane': 'red'}
scatter = ax.scatter(np.log2(merged['clip_enrichment']),
        np.log2(merged['rden_change']), 
        s=0.1, 
        c = merged['type'].map(lambda x: color_dict.get(x)).dropna(),
        alpha = 0.5)

# c = merged['type'].map(lambda x: color_dict.get(x)).dropna(), label=color_dict.keys(),

# Set legend labels as color_dict keys
legend_labels = list(color_dict.keys())

# Create scatter plot handles for each category
handles = [plt.Line2D([], [], marker='.', linestyle='', color=color, label=label) for label, color in color_dict.items()]


# Create legend with scatter plot handles and labels
ax.legend(handles=handles, labels=legend_labels, loc='upper left', fontsize=8)

ß
ax.set_xlabel('LIN28A CLIP enrichment ($\log_2$)', fontsize='large')
ax.set_ylabel('Ribosome density change\nupon $\it{LIN28A}$ knockdown ($\log_2$)', fontsize='large')
#title left ordered
ax.set_title('CLIP and ribosome footprinting upon\n$\it{Lin28a}$ knockdown\n', loc='left')
# Out:
# <>:32: SyntaxWarning: invalid escape sequence '\l'
# <>:33: SyntaxWarning: invalid escape sequence '\i'
# <>:35: SyntaxWarning: invalid escape sequence '\i'
# <>:32: SyntaxWarning: invalid escape sequence '\l'
# <>:33: SyntaxWarning: invalid escape sequence '\i'
# <>:35: SyntaxWarning: invalid escape sequence '\i'
# /tmp/ipykernel_794804/1870221971.py:32: SyntaxWarning: invalid escape sequence '\l'
#   ax.set_xlabel('LIN28A CLIP enrichment ($\log_2$)', fontsize='large')
# /tmp/ipykernel_794804/1870221971.py:33: SyntaxWarning: invalid escape sequence '\i'
#   ax.set_ylabel('Ribosome density change\nupon $\it{LIN28A}$ knockdown ($\log_2$)', fontsize='large')
# /tmp/ipykernel_794804/1870221971.py:35: SyntaxWarning: invalid escape sequence '\i'
#   ax.set_title('CLIP and ribosome footprinting upon\n$\it{Lin28a}$ knockdown\n', loc='left')
# Text(0.0, 1.0, 'CLIP and ribosome footprinting upon\n$\\it{Lin28a}$ knockdown\n')
